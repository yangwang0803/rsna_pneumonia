# %%
import os
import pandas as pd
import numpy as np
from glob import glob

import pydicom

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns

# %%
# data
data_raw = pd.read_csv(r'C:\Users\3594997\Study\Kaggle\Pneumonia\data\work_1.csv')
print(len(data_raw))
data_raw.head()
# Out:
# 28989
#                               patientId      x      y  width  height  target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
#
#                           class
# 0  No Lung Opacity / Not Normal
# 1  No Lung Opacity / Not Normal
# 2  No Lung Opacity / Not Normal
# 3                        Normal
# 4                  Lung Opacity

# %%
# dir
dir_train = r'C:\Users\3594997\Study\Kaggle\Pneumonia\data\stage_1_train_images'
dir_test = r'C:\Users\3594997\Study\Kaggle\Pneumonia\data\stage_1_test_images'

# %%
df = pd.DataFrame({'path': glob(os.path.join(dir_train, '*.dcm'))})
df['patientId'] = df['path'].map(lambda x: os.path.splitext(os.path.basename(x))[0])
print(len(df))
df.head()
# Out:
# 25684
#                                                 path  \
# 0  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 1  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 2  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 3  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 4  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
#
#                               patientId
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd
# 2  00322d4d-1c29-4943-afc9-b6754be640eb
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5
# 4  00436515-870c-4b36-a041-de91049b9ab4

# %%
DCM_TAG_LIST = ['PatientAge', 'BodyPartExamined', 'ViewPosition', 'PatientSex']
def get_tags(in_path):
    c_dicom = pydicom.read_file(in_path, stop_before_pixels=True)
    tag_dict = {c_tag: getattr(c_dicom, c_tag, '') 
         for c_tag in DCM_TAG_LIST}
    tag_dict['path'] = in_path
    return pd.Series(tag_dict)
image_meta_df = df.apply(lambda x: get_tags(x['path']), 1)
# show the summary
image_meta_df['PatientAge'] = image_meta_df['PatientAge'].map(int)

# %%
len(image_meta_df)
image_meta_df
# Out:
#        PatientAge BodyPartExamined ViewPosition PatientSex  \
# 0              51            CHEST           PA          F
# 1              48            CHEST           PA          F
# 2              19            CHEST           AP          M
# 3              28            CHEST           PA          M
# 4              32            CHEST           AP          F
# 5              54            CHEST           AP          M
# 6              78            CHEST           PA          M
# 7              75            CHEST           PA          M
# 8              59            CHEST           PA          F
# 9              63            CHEST           PA          M
# 10             54            CHEST           PA          F
# 11             48            CHEST           PA          M
# 12              6            CHEST           AP          F
# 13             23            CHEST           AP          F
# 14             70            CHEST           PA          M
# 15             58            CHEST           AP          M
# 16             36            CHEST           PA          M
# 17             28            CHEST           PA          F
# 18             43            CHEST           PA          M
# 19             21            CHEST           AP          M
# 20             52            CHEST           PA          M
# 21             60            CHEST           AP          M
# 22             71            CHEST           AP          M
# 23             50            CHEST           PA          F
# 24             54            CHEST           PA          M
# 25             23            CHEST           AP          M
# 26             38            CHEST           PA          M
# 27             47            CHEST           PA          F
# 28             67            CHEST           AP          F
# 29             44            CHEST           PA          M
# ...           ...              ...          ...        ...
# 25654          32            CHEST           PA          F
# 25655          61            CHEST           PA          F
# 25656          37            CHEST           AP          M
# 25657          71            CHEST           PA          M
# 25658          27            CHEST           PA          F
# 25659          42            CHEST           PA          M
# 25660          19            CHEST           AP          M
# 25661          50            CHEST           PA          M
# 25662          71            CHEST           AP          F
# 25663          33            CHEST           AP          M
# 25664          54            CHEST           AP          M
# 25665          56            CHEST           PA          F
# 25666          58            CHEST           AP          M
# 25667          58            CHEST           PA          M
# 25668          62            CHEST           PA          M
# 25669          42            CHEST           PA          F
# 25670          58            CHEST           PA          M
# 25671          31            CHEST           PA          M
# 25672          45            CHEST           PA          F
# 25673          27            CHEST           PA          M
# 25674          36            CHEST           AP          F
# 25675          62            CHEST           AP          M
# 25676          58            CHEST           PA          F
# 25677          41            CHEST           AP          M
# 25678          67            CHEST           PA          M
# 25679          46            CHEST           AP          M
# 25680          31            CHEST           PA          M
# 25681          30            CHEST           AP          F
# 25682          47            CHEST           PA          M
# 25683          45            CHEST           AP          M
#
#                                                     path
# 0      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 1      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 2      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 3      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 4      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 5      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 6      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 7      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 8      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 9      C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 10     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 11     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 12     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 13     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 14     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 15     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 16     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 17     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 18     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 19     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 20     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 21     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 22     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 23     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 24     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 26     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 27     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 28     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 29     C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# ...                                                  ...
# 25654  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25655  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25656  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25657  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25658  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25659  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25660  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25661  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25662  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25663  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25664  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25665  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25666  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25667  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25668  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25669  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25670  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25671  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25672  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25673  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25674  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25675  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25676  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25677  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25678  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25679  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25680  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25681  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25682  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 25683  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
#
# [25684 rows x 5 columns]

# %%
df = df.merge(image_meta_df, on='path', how='inner')
print(len(df))
df.head()
# Out:
# 25684
#                                                 path  \
# 0  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 1  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 2  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 3  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
# 4  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...
#
#                               patientId  PatientAge BodyPartExamined  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6          51            CHEST
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd          48            CHEST
# 2  00322d4d-1c29-4943-afc9-b6754be640eb          19            CHEST
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5          28            CHEST
# 4  00436515-870c-4b36-a041-de91049b9ab4          32            CHEST
#
#   ViewPosition PatientSex
# 0           PA          F
# 1           PA          F
# 2           AP          M
# 3           PA          M
# 4           AP          F

# %%
data_raw = data_raw.merge(df, on='patientId', how='inner')
print(len(data_raw))
data_raw.head()
# Out:
# 28989
#                               patientId      x      y  width  height  target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
#
#                           class  \
# 0  No Lung Opacity / Not Normal
# 1  No Lung Opacity / Not Normal
# 2  No Lung Opacity / Not Normal
# 3                        Normal
# 4                  Lung Opacity
#
#                                                 path  PatientAge  \
# 0  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          51
# 1  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          48
# 2  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          19
# 3  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          28
# 4  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          32
#
#   BodyPartExamined ViewPosition PatientSex
# 0            CHEST           PA          F
# 1            CHEST           PA          F
# 2            CHEST           AP          M
# 3            CHEST           PA          M
# 4            CHEST           AP          F

# %%
data_raw.drop(columns='BodyPartExamined', inplace=True)
data_raw.head()
# Out:
#                               patientId      x      y  width  height  target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
#
#                           class  \
# 0  No Lung Opacity / Not Normal
# 1  No Lung Opacity / Not Normal
# 2  No Lung Opacity / Not Normal
# 3                        Normal
# 4                  Lung Opacity
#
#                                                 path  PatientAge ViewPosition  \
# 0  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          51           PA
# 1  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          48           PA
# 2  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          19           AP
# 3  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          28           PA
# 4  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          32           AP
#
#   PatientSex
# 0          F
# 1          F
# 2          M
# 3          M
# 4          F

# %%
data_raw = data_raw.assign(NumBox = data_raw.groupby('patientId').path.transform(lambda x: len(x)))
data_raw.head(10)
# Out:
#                               patientId      x      y  width  height  target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
# 5  00436515-870c-4b36-a041-de91049b9ab4  562.0  152.0  256.0   453.0       1
# 6  00569f44-917d-4c86-a842-81832af98c30    NaN    NaN    NaN     NaN       0
# 7  006cec2e-6ce2-4549-bffa-eadfcd1e9970    NaN    NaN    NaN     NaN       0
# 8  00704310-78a8-4b38-8475-49f4573b2dbb  323.0  577.0  160.0   104.0       1
# 9  00704310-78a8-4b38-8475-49f4573b2dbb  695.0  575.0  162.0   137.0       1
#
#                           class  \
# 0  No Lung Opacity / Not Normal
# 1  No Lung Opacity / Not Normal
# 2  No Lung Opacity / Not Normal
# 3                        Normal
# 4                  Lung Opacity
# 5                  Lung Opacity
# 6  No Lung Opacity / Not Normal
# 7  No Lung Opacity / Not Normal
# 8                  Lung Opacity
# 9                  Lung Opacity
#
#                                                 path  PatientAge ViewPosition  \
# 0  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          51           PA
# 1  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          48           PA
# 2  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          19           AP
# 3  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          28           PA
# 4  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          32           AP
# 5  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          32           AP
# 6  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          54           AP
# 7  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          78           PA
# 8  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          75           PA
# 9  C:\Users\3594997\Study\Kaggle\Pneumonia\data\s...          75           PA
#
#   PatientSex  NumBox
# 0          F       1
# 1          F       1
# 2          M       1
# 3          M       1
# 4          F       2
# 5          F       2
# 6          M       1
# 7          M       1
# 8          M       2
# 9          M       2

# %%
data_raw.to_csv('work_2.csv', index=False)
